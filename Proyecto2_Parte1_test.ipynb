# %% [markdown]
# # Proyecto # 2
# Cristina Bautista - 161260
#
# Abril Palencia - 18198

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %matplotlib inline

# %%
df = pd.read_csv('test.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(2)
# Out:
#                   MachineIdentifier   ProductName EngineVersion   AppVersion  \
# 0  0000010489e3af074adeac69c53e555e  win8defender   1.1.15400.5  4.18.1810.5
# 1  00000176ac758d54827acd545b6315a5  win8defender   1.1.15400.4  4.18.1809.2
#
#   AvSigVersion  IsBeta  RtpStateBitfield  IsSxsPassiveMode  \
# 0  1.281.501.0       0               7.0                 0
# 1  1.279.301.0       0               7.0                 0
#
#    DefaultBrowsersIdentifier  AVProductStatesIdentifier  ...  \
# 0                        NaN                    53447.0  ...
# 1                        NaN                    53447.0  ...
#
#    Census_FirmwareManufacturerIdentifier  Census_FirmwareVersionIdentifier  \
# 0                                  807.0                            8554.0
# 1                                  554.0                           33105.0
#
#    Census_IsSecureBootEnabled  Census_IsWIMBootEnabled  \
# 0                           1                      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7853253 entries, 0 to 7853252
# Data columns (total 82 columns):
#  #   Column                                             Dtype
# ---  ------                                             -----
#  0   MachineIdentifier                                  object
#  1   ProductName                                        object
#  2   EngineVersion                                      object
#  3   AppVersion                                         object
#  4   AvSigVersion                                       object
#  5   IsBeta                                             int64
#  6   RtpStateBitfield                                   float64
#  7   IsSxsPassiveMode                                   int64
#  8   DefaultBrowsersIdentifier                          float64
#  9   AVProductStatesIdentifier                          float64
#  10  AVProductsInstalled                                float64
# ...

# %%
df = df.drop(labels=["MachineIdentifier", "ProductName", "IsBeta", "RtpStateBitfield"
                     , "IsSxsPassiveMode", "AVProductsInstalled", "AVProductsEnabled"
                     , "DefaultBrowsersIdentifier", "HasTpm", "GeoNameIdentifier"
                     , "Census_IsVirtualDevice", "OsBuildLab", "AutoSampleOptIn", "IeVerIdentifier",
                    "Census_MDC2FormFactor", "Census_OEMNameIdentifier", "Census_OEMModelIdentifier"
                    , "Census_ProcessorCoreCount", "Census_ProcessorManufacturerIdentifier", 
                    "Census_ProcessorModelIdentifier", "Census_ProcessorClass", 
                     "Census_PrimaryDiskTotalCapacity", "Census_PrimaryDiskTypeName",
                    "Census_SystemVolumeTotalCapacity", "Census_HasOpticalDiskDrive", "Census_TotalPhysicalRAM"
                    , "Census_ChassisTypeName", "Census_InternalPrimaryDiagonalDisplaySizeInInches"
                    , "Census_InternalPrimaryDisplayResolutionHorizontal", 
                     "Census_InternalPrimaryDisplayResolutionVertical", "Census_PowerPlatformRoleName"
                    , "Census_InternalBatteryType", "Census_InternalBatteryNumberOfCharges"
                    , "Census_OSVersion", "Census_OSArchitecture", "Census_OSBranch", "Census_OSBuildNumber"
                    , "Census_OSBuildRevision", "Census_OSEdition", "Census_OSSkuName", "Census_OSInstallTypeName"
                    , "Census_OSInstallLanguageIdentifier", "Census_OSUILocaleIdentifier"
                    , "Census_OSWUAutoUpdateOptionsName", "Census_IsPortableOperatingSystem", 
                     "Census_GenuineStateName", "Census_ActivationChannel", "Census_IsFlightingInternal"
                    , "Census_IsFlightsDisabled", "Census_FlightRing", "Census_ThresholdOptIn"
                    , "Census_IsTouchEnabled", "Census_IsPenCapable", "Census_IsAlwaysOnAlwaysConnectedCapable"
                    , "Wdft_IsGamer", "Wdft_RegionIdentifier", "CityIdentifier", 
                     "OrganizationIdentifier", "PuaMode", "AvSigVersion"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7853253 entries, 0 to 7853252
# Data columns (total 22 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   EngineVersion                          object
#  1   AppVersion                             object
#  2   AVProductStatesIdentifier              float64
#  3   CountryIdentifier                      int64
#  4   LocaleEnglishNameIdentifier            int64
#  5   Platform                               object
#  6   Processor                              object
#  7   OsVer                                  object
#  8   OsBuild                                int64
#  9   OsSuite                                int64
#  10  OsPlatformSubRelease                   object
#  11  SkuEdition                             object
#  12  IsProtected                            float64
#  13  SMode                                  float64
# ...

# %%
df.isna()
# Out:
#          EngineVersion  AppVersion  AVProductStatesIdentifier  \
# 0                False       False                      False
# 1                False       False                      False
# 2                False       False                      False
# 3                False       False                      False
# 4                False       False                      False
# ...                ...         ...                        ...
# 7853248          False       False                      False
# 7853249          False       False                      False
# 7853250          False       False                      False
# 7853251          False       False                      False
# 7853252          False       False                      False
#
#          CountryIdentifier  LocaleEnglishNameIdentifier  Platform  Processor  \
# 0                    False                        False     False      False
# ...

# %%
df.isna().sum()
# Out:
# EngineVersion                                  0
# AppVersion                                     0
# AVProductStatesIdentifier                  23767
# CountryIdentifier                              0
# LocaleEnglishNameIdentifier                    0
# Platform                                       0
# Processor                                      0
# OsVer                                          0
# OsBuild                                        0
# OsSuite                                        0
# OsPlatformSubRelease                           0
# SkuEdition                                     0
# IsProtected                                23649
# SMode                                    5831272
# SmartScreen                              3498402
# Firewall                                   58472
# UacLuaenable                                7865
# Census_DeviceFamily                            0
# Census_FirmwareManufacturerIdentifier     198634
# ...

# %%
df = df.drop(labels=["SmartScreen", "Census_IsWIMBootEnabled", "AVProductStatesIdentifier"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7853253 entries, 0 to 7853252
# Data columns (total 19 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   EngineVersion                          object
#  1   AppVersion                             object
#  2   CountryIdentifier                      int64
#  3   LocaleEnglishNameIdentifier            int64
#  4   Platform                               object
#  5   Processor                              object
#  6   OsVer                                  object
#  7   OsBuild                                int64
#  8   OsSuite                                int64
#  9   OsPlatformSubRelease                   object
#  10  SkuEdition                             object
#  11  IsProtected                            float64
#  12  SMode                                  float64
#  13  Firewall                               float64
# ...

# %%
df = df.sample(n = 1000000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 5385787 to 5314501
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   EngineVersion                          1000000 non-null  object
#  1   AppVersion                             1000000 non-null  object
#  2   CountryIdentifier                      1000000 non-null  int64
#  3   LocaleEnglishNameIdentifier            1000000 non-null  int64
#  4   Platform                               1000000 non-null  object
#  5   Processor                              1000000 non-null  object
#  6   OsVer                                  1000000 non-null  object
#  7   OsBuild                                1000000 non-null  int64
#  8   OsSuite                                1000000 non-null  int64
#  9   OsPlatformSubRelease                   1000000 non-null  object
# ...

# %%
df.to_csv("sample_test.csv")

# %%
df.head()
# Out:
#         EngineVersion      AppVersion  CountryIdentifier  \
# 5385787   1.1.15400.4     4.18.1809.2                207
# 1366005   1.1.15400.4  4.9.10586.1106                207
# 5432072   1.1.15400.5     4.18.1810.5                207
# 3051878   1.1.15400.5     4.18.1810.5                 85
# 3117982   1.1.15300.6     4.18.1809.2                158
#
#          LocaleEnglishNameIdentifier   Platform Processor     OsVer  OsBuild  \
# 5385787                           75  windows10       x64  10.0.0.0    17134
# 1366005                           75  windows10       x64  10.0.0.0    10586
# 5432072                           75  windows10       x64  10.0.0.0    17134
# 3051878                          225  windows10       x64  10.0.0.0    17134
# 3117982                           75  windows10       x64  10.0.0.0    17134
#
#          OsSuite OsPlatformSubRelease SkuEdition  IsProtected  SMode  \
# 5385787      256                  rs4        Pro          1.0    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 5385787 to 5314501
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   EngineVersion                          1000000 non-null  object
#  1   AppVersion                             1000000 non-null  object
#  2   CountryIdentifier                      1000000 non-null  int64
#  3   LocaleEnglishNameIdentifier            1000000 non-null  int64
#  4   Platform                               1000000 non-null  object
#  5   Processor                              1000000 non-null  object
#  6   OsVer                                  1000000 non-null  object
#  7   OsBuild                                1000000 non-null  int64
#  8   OsSuite                                1000000 non-null  int64
#  9   OsPlatformSubRelease                   1000000 non-null  object
# ...
